# %% [markdown]
# # 🎵 Pure Synthetic Songs
#
# This tutorial explains how to generate pure synthetic songs through the motor gestures. For this guide, there is not need of recording sample, however you must define the project directory.
#
# ::::{admonition} Google Colab Execution
# :class: dropdown
#
# If you are using Google Colab install the pacakge via pypi with the following code:
#
# :::{code} bash
# ! pip install wavesongs
# :::
#
#
# ::::

# %% [markdown]
# ## Libraries
#
# Import the required classes and functions from `wavesongs`:

# %%
from wavesongs.util import plot
from wavesongs.object import Synthetic
from wavesongs.data import ProjDirs

proj_dirs = ProjDirs(audios="./assets/audios", results="./assets/results_pure_synthetic")
ploter = plot.set_plotter(library="matplotlib")

import numpy as np
sr = 44100
t = np.linspace(0, 1, sr)
x = np.sin(2 * np.pi * 2000 * t) # + np.sin(2 * np.pi * 3500 * t)

synthetic = Synthetic(duration=1, proj_dirs=proj_dirs, sr=sr)
synthetic.initialize(x)

synthetic.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetic)#, ylim=(0, 0.5))

# %%
from wavesongs.core.bird import Model

model = Model(ovsr=4)

# %%
ploter._COLORS["motor_gesture"] = "Grays"
# Define control parameters and generate gesture
z = {"a0": 0.05, "b0": 0.1, "b1": -0.25, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import time
import numpy

def linear(t, wi, wf, ti, tf):
    return wi + (wf - wi) * ((t - ti) / (tf - ti))

def exponential(t, wi, wf, ti, tf, factor=3):
    alpha = factor * (t - ti) / (tf - ti)
    return wi + (wf - wi) * (1 - np.exp(-alpha)) / (1 - np.exp(-factor))

def sinusoidal(t, wi, wf, ti, tf, phase_shift=0):
    wav = (wi + wf) / 2
    A = (wf - wi) / 2
    return wav + A * np.sin(phase_shift + np.pi * (t - ti) / (tf - ti))

start_time = time.perf_counter()
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
# z = {"a0": 0.05, "b0": 0.2, "b1": 0.25, "b2": 0}
# curves = model.control_parameters(synthetic, z, beta_mode="poly")
t_ones = np.linspace(0, 1/2, sr)
# curves = [0.01*t+0.04, exponential(t, 1, 0.2, 0, 1)]
curves = [0.01*t+0.04, sinusoidal(t, 0.2, 1, 0, 0.05, np.pi/2)]
synthetized = model.motor_gesture(synthetic, curves)

end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.6f} seconds")

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
# Elapsed time: 21.228450 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import time
import numpy

def linear(t, wi, wf, ti, tf):
    return wi + (wf - wi) * ((t - ti) / (tf - ti))

def exponential(t, wi, wf, ti, tf, factor=3):
    alpha = factor * (t - ti) / (tf - ti)
    return wi + (wf - wi) * (1 - np.exp(-alpha)) / (1 - np.exp(-factor))

def sinusoidal(t, wi, wf, ti, tf, phase_shift=0):
    wav = (wi + wf) / 2
    A = (wf - wi) / 2
    return wav + A * np.sin(phase_shift + np.pi * (t - ti) / (tf - ti))

start_time = time.perf_counter()
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
# z = {"a0": 0.05, "b0": 0.2, "b1": 0.25, "b2": 0}
# curves = model.control_parameters(synthetic, z, beta_mode="poly")
t_ones = np.linspace(0, 1/2, sr)
# curves = [0.01*t+0.04, exponential(t, 1, 0.2, 0, 1)]
curves = [0.01*t+0.04, sinusoidal(t, 1, 0.2, 0, 1, np.pi/2)]
synthetized = model.motor_gesture(synthetic, curves)

end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.6f} seconds")

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
# Elapsed time: 71.991736 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Grays"
# Define control parameters and generate gesture
z = {"a0": -0.005, "b0": 0.2, "b1": -0.25, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Grays"
# Define control parameters and generate gesture
z = {"a0": -0.005, "b0": 0.175, "b1": -0.25, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Grays"
# Define control parameters and generate gesture
z = {"a0": 0.005, "b0": 0.2, "b1": -0.15, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Greens"
# Define control parameters and generate gesture
# z = {"a0": 0.15, "a1": 0.15, "a2": 0,"b0": 0.15, "b1": -0.15, "b2": 0}
z = {"a0": 0.15, "b0": 0.15, "b1": -0.15, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()

# %%
ploter._COLORS["motor_gesture"] = "Purples"

# Define control parameters and generate gesture
# z = {"a0": 0.15, "a1": 0.15, "a2": 0,"b0": 0.15, "b1": -0.15, "b2": 0}
z = {"a0": 0.15, "b0": 0.6, "b1": -0.15, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Reds"

# Define control parameters and generate gesture
z = {"a0": 0.005, "b0": 1.1, "b1": -0.15, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter.physical_variables(synthetized)

# %%
ploter._COLORS["motor_gesture"] = "Reds"

# Define control parameters and generate gesture
z = {"a0": 0.005, "b0": 0.2, "b1": -0.15, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Purples"
# Define control parameters and generate gesture
z = {"a0": 0.05, "b0": 1.1, "b1": -0.15, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
z = {"a0": 0.25, "b0": 0.7, "b1": -0.25, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
z = {"a0": 0.05, "b0": 0.7, "b1": -0.25, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
z = {"a0": 0.05, "b0": 0.7, "b1": 0.25, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
z = {"a0": 0.05, "b0": 0.2, "b1": 0.25, "b2": 0}
curves = model.control_parameters(synthetic, z, beta_mode="poly")
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Lissajous

# %%
synthetic = Synthetic(duration=1, proj_dirs=proj_dirs, sr=sr)
synthetic.initialize()

ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
# z = {"a0": 0.05, "b0": 0.2, "b1": 0.25, "b2": 0}
# curves = model.control_parameters(synthetic, z, beta_mode="poly")

z = {"a0": 0.05, "a1":0.02, "a2": 10, "a3":0, "b0": 0.1, "b1": -0.2, "b2": 6, "b3": 1/8}
synthetic.z = z
alpha = z["a0"] + z["a1"] * np.cos(2 * np.pi * (z["a2"] * t + z["a3"])) # a0 + a1*sin(2pi a2 t)
beta = z["b0"] + z["b1"] * np.cos(2 * np.pi * (z["b2"] * t + z["b3"])) # b0 + b1*sin(2pi (b2*t+ b3))
curves = [alpha, beta]
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)#, ylim=(0, 0.5))
synthetized.play()

print(f"alpha = {z['a0']} + {z['a1']} * cos(2 * pi * ({z['a2']} * t + {z['a3']}))\n"
      f"beta = {z['b0']} + {z['b1']} * cos(2 * pi * ({z['b2']} * t + {z['b3']})) ")
# Out:
# alpha = 0.05 + 0.02 * cos(2 * pi * (10 * t + 0))
# beta = 0.1 + -0.2 * cos(2 * pi * (6 * t + 0.125))

# %%
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
z = {"a0": 0.05, "b0": 0.2, "b1": 0.25, "b2": 0}
# curves = model.control_parameters(synthetic, z, beta_mode="poly")
curves = [0.05*np.ones_like(t), 0.4*np.ones_like(t)+0.01*t]
synthetized = model.motor_gesture(synthetic, curves[::1])

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ploter._COLORS["motor_gesture"] = "Blues"
# Define control parameters and generate gesture
z = {"a0": 0.05, "b0": 0.2, "b1": 0.25, "b2": 0}
# curves = model.control_parameters(synthetic, z, beta_mode="poly")
t_ones = np.ones_like(t)
curves = [0.1*t**2+0.05, 0.4*t_ones+0.01*t]
synthetized = model.motor_gesture(synthetic, curves)

# Plot
_ = ploter.alpha_beta(synthetized, save=False)

# Plot waveforme generated
synthetized.acoustical_features(umbral_FF=1.4, n_fft=512, ff_method="yin")
_ = ploter.spectrogram(synthetized, save=False)
synthetized.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Synthetic Syllable

# %% [markdown]
# ### Project Directory

# %% [markdown]
# ### Base Syllable
#
# First, let's create a base syllable with a defined duration and a sample rate. The object created is a simple pulse of amplitud 1.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/ws/lib/python3.13/site-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~/anaconda3/envs/ws/lib/python3.13/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     400                         return meth(obj, self, cycle)
#     401                 if (
# ...

# %%
synth = Synthetic(duration=0.1, file_id="00001", proj_dirs=proj_dirs, sr=44100)
# add plot

# %% [markdown]
# ### Motor Gesture
#
# The next step is to define the motor gesture coefficients. These coefficients will generate the air-sac pressure and labial tension curves, forming the motor gesture. This will produce a synthetic syllable, for which we need to compute its acoustical features by defining some spectral parameters.

# %%
# Motor gesture coefficients
from wavesongs.core.bird import Model, Solver

z = {
    "a0": 0.11,
    "b0": -0.1,
    "b1": 1, 
    "b2": 0,
}

model = Model()
curves = model.control_parameters(synth, z, beta_method="parabola")
synth = model.motor_gesture(synth, curves)
synth.acoustical_features(umbral_FF=1.4, n_fft=256, ff_method="yin", flim=(1e2, 2e4))

plotter = plot.set_plotter("plotly")
plotter.spectrogram(synth, ff=True)

# %%
synth.play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Curves

# %%
plotter.alpha_beta(synth, save=False)

# %% [markdown]
# ## Tunning Coefficients
#
# As you experienced, the motor gesture is out of the region of oscillations (gray region), so the audio generated is not correct. The beginning of the audio is missing because the beginning of the motor gesture is below the saddle node line. To improve the song created, the motor gesture has to be moved inside the region. This can be done in several ways, but here is a short description of the model behavior: to get more harmonics in the song, more close or separeted, move the motor gesture to the left; to get lower or higher fundamental frequencies, move the motor gesture down or up, respectively.
#
# It is also possible to get very low or high fundamental frequency by changing the time scale parameter, $\gamma$. To do that, modify the `gm` key of the `_PARAMS` dictionary. The default value is 40000.

# %%
z_opt = {
    "a0": 0.11,
    "b0": 0.1,
    "b1": 0.1, 
    "b2": 0,
}

curves = model.control_parameters(synth, z_opt, beta_method="parabola")
synth_opt = model.motor_gesture(synth, curves)
synth_opt.acoustical_features(umbral_FF=1.4, n_fft=256, ff_method="yin", flim=(1e2, 2e4))
plotter.spectrogram(synth_opt, ff=True)

# %% [markdown]
# There you go!
#
# The song obtained is much better because the beginning of the motor gesture is close to the saddle node line. The harmonics are stronger than the fundamental frequency, and it is not well computed. Although this can be improved, we are interested in demonstrating this behavior since it can affect the synthetic score. So, take it in account when you are generating synthetic syllables from recording examples.

# %%
synth_opt.play()

# %% [markdown]
# ### Motor Gesture Curves

# %%
plotter.alpha_beta(synth_opt, save=False)

# %% [markdown]
# <hr>
#
# This tutorial demonstrated how the physical model behaves and how the coefficients improve or worsen the resulting synthetic syllable. Now it is your time to play with the coefficients and generate the syllable you want. You can generate not just lines but also quadratic curves by changing the values, especially `b0`.
